# %%
import pandas as pd
from bokeh.io import output_notebook
output_notebook()
bokeh_width, bokeh_height = 500,400
# Out:
# <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
df = pd.read_csv('areasurvey.csv')
df.head()
# Out:
#    Unnamed: 0     price  area_tot  area_build       lon        lat
# 0       83897  741139.0     386.0         0.0  6.072922  46.319225
# 1       83912  716500.0    2731.0         0.0  6.072922  46.319225
# 2       83927   15000.0     727.0         0.0  6.072922  46.319225
# 3       83957  741139.0     338.0         0.0  6.068902  46.323598
# 4       83997  582000.0    4643.0         0.0  6.072211  46.316697

# %%
# Setting up your API key
# %env GOOGLE_API_KEY = 'your_API_key'

# %% [raw]
# # getting the cordinate of a place/area
# type on google name of the area interested in followed by lat lon

# %%
# choosing and setting an area as center of the map
lat, lon = 46.2437, 6.0251

# %%
# Reading the API key
import os 
api_key = os.environ['GOOGLE_API_KEY']

# %%
# Displaying a Simple Dynamic Map

# %%
from bokeh.io import show
from bokeh.plotting import gmap
from bokeh.models import GMapOptions

def plot_map(lat, lng, zoom=10, map_type='roadmap'):
    gmap_options = GMapOptions(lat=lat, lng=lng, 
                               map_type=map_type, zoom=zoom)
    p = gmap(api_key, gmap_options, title='Pays de Gex', 
             width=bokeh_width, height=bokeh_height)
    show(p)
    return p

# %%
p = plot_map(46.319225, 6.072922)
# Out:
#   <div class="bk-root" id="af7b4c0a-a3c4-4b24-8fc0-eba529980e32" data-root-id="1444"></div>

# %%
def plot_map(lat, lng, zoom=10, map_type='roadmap'):
    gmap_options = GMapOptions(lat=lat, lng=lng, 
                               map_type=map_type, zoom=zoom)
    p = gmap(api_key, gmap_options, title='Pays de Gex', 
             width=bokeh_width, height=bokeh_height)
    # beware, longitude is on the x axis ;-)
    center = p.circle([lng], [lat], size=10, alpha=0.5, color='red')
    show(p)
    return p

p = plot_map(lat, lon, map_type='terrain')
# Out:
#   <div class="bk-root" id="db9b4782-7492-467c-9c93-637351557c97" data-root-id="1550"></div>
